# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !python "/gdrive/MyDrive/Data Science/UNI/AML/Final Project/Test 2 Train Code/esrgan/esrgan.py"
# Out:
# Namespace(b1=0.9, b2=0.999, batch_size=1, channels=3, checkpoint_interval=5000, decay_epoch=100, epoch=0, hr_height=480, hr_width=640, lambda_adv=0.005, lambda_pixel=0.01, lr=0.0002, n_cpu=8, n_epochs=1, residual_blocks=23, sample_interval=100, warmup_batches=1)
# 0
# 1
# [Epoch 0/1] [Batch 0/3] [G pixel: 0.919811]
# 1
# 1
# Here!-----> torch.Size([1, 1, 30, 30]) torch.Size([1, 1, 30, 30]) (1, 30, 30)
# OKKKKKKKK
# [Epoch 0/1] [Batch 1/3] [D loss: 0.722917] [G loss: 2.010322, content: 1.999944, adv: 0.718295, pixel: 0.678681]
# 2
# 1
# Here!-----> torch.Size([1, 1, 30, 30]) torch.Size([1, 1, 30, 30]) (1, 30, 30)
# OKKKKKKKK
# Traceback (most recent call last):
#   File "/gdrive/MyDrive/Data Science/UNI/AML/Final Project/Test 2 Train Code/esrgan/esrgan.py", line 146, in <module>
#     real_features = feature_extractor(imgs_hr).detach()
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
# ...

# %%
256//4
# Out:
# 64
